# %%
import numpy as np
import pandas as pd

# %% [markdown]
# file name -> Columns
#
# quater-i.csv -> ['order_id', 'quantity', 'item_id', 'choice_description_id' 'item_price']
#
# items.csv -> ['item_id', 'item_name']

# %%
# import like this
items_path = "items.csv"
q1_path = "quarter-1.csv"
q2_path = "quarter-2.csv"
q3_path = "quarter-3.csv"


q1= pd.read_csv(q1_path)
q2 = pd.read_csv(q2_path)
q3 = pd.read_csv(q3_path)

items = pd.read_csv(items_path)

# %% [markdown]
# ### `Q:1-5`
# 1. You are given three quater files, your job is to append these three files and make a single dataframe.
# 2. Have a index as Q-1 Q-2 Q-3 for respective quater files in the dataframe
# 3. Your are given a file items.csv which has item_id and item_name. Find out most sold items in each quarter.
# 4. Find out items which has made most revenue in each quarter.
# 5. Find out avg order price of each quarter.
#
# ***Note: item_price is given as str with $ sign, in earlier task you have converted this to rupees, here too first convert item_price field in rupees.***

# %% [markdown]
# ### `Q-6` From the IPL wala dataset you have to find the Purple cap holder each season.
#
# *Note: Bowler with most no wickets in a season gets purple cap. If more than one bowler have same no of wickets in the season, one with least ecomnomy among them is purple cap holder.*
#
# Bowler's Economy = runs-conceded per six ballsum

# %%
balls = pd.read_csv("IPL_Ball_by_Ball_2008_2022.csv")
matches = pd.read_csv("IPL_Matches_2008_2022.csv")

# %%
df1=pd.concat((q1,q2,q3))

# %%
df22=pd.concat((q1,q2,q3), axis=0, keys=["Q1", "Q2", "Q3"])

# %% [markdown]
# Best bowler in death overs.
# Note: Have taken most no of wickets in case of tie with least economy
#
# Death Overs - [16-20]

# %%
# Out:
#          bowler  IsBowlerWicket  BowlerRun  IsLegalBall   Economy
# 91     DJ Bravo             115       2161         1385  9.361733
# 331  SL Malinga             108       1464         1117  7.863921
# 53      B Kumar              90       1752         1173  8.961637
# 148   JJ Bumrah              80       1614         1146  8.450262
# 339   SP Narine              67       1164          949  7.359326

# %% [markdown]
# ### `Q-8` Batsman record season wise
#
# Make a function which takes a input `batsman_name` and it returns a dataframe.
# Columns of the data frame are - `['Season','Innings', 'TotalRuns', 'Avg', 'HighestScore','StrikeRate']`.
# * In result make `Season` column as index.
#
# * Avg - total_runs/ no of time got out. - player_out column will help.
# * StrikeRate -(total_runs/ balls faced) * 100- wides are not included in batsman ball faced counts. No balls are included. -> Extra_type column will help
# * Batsman Can score runs on No Balls.
# * Batsman can get out on No Ball or Wides. And even while being on non-striker. Keep these things in mind before masking.

# %%
# code here
batterdf = seasondf.copy()
batterdf["IsBatsmanBall"] = batterdf["extra_type"].apply(lambda x: 1 if x != "wides" else 0)

def bat_record_season(batsman):
    bdf = batterdf[batterdf.batter == batsman].copy()
    bdf["IsBatsmanOut"] = bdf.batter == bdf.player_out
    df = bdf.groupby(["Season", "ID"], as_index = False)[["batsman_run", "IsBatsmanBall", "IsBatsmanOut"]].sum()
    innings = df.groupby("Season").ID.count()
    df = df.groupby("Season").agg(
    {
        "batsman_run":["sum", "max"],
        "IsBatsmanBall": "sum",
        "IsBatsmanOut": "sum"
    })
    df["Innings"]= innings
    df["TotalRuns"] = df[("batsman_run", "sum")]
    df["Avg"] = df["TotalRuns"] / df[("IsBatsmanOut", "sum")]
    df["HighestScore"] = df[("batsman_run", "max")]
    df["StrikeRate"] = df["TotalRuns"] / df[("IsBatsmanBall", "sum")] * 100
    return df.drop(columns = ["batsman_run", "IsBatsmanBall", "IsBatsmanOut"])
bat_record_season("MS Dhoni")
# Out:
#         Innings TotalRuns         Avg HighestScore  StrikeRate
#
# Season
# 2007/08      14       414   41.400000           65  133.548387
# 2009         13       332   41.500000           58  127.203065
# 2009/10      11       287   31.888889           66  136.666667
# 2011         13       392   43.555556           70  158.704453
# 2012         17       358   32.545455           51  128.776978
# 2013         16       461   46.100000           67  162.897527
# 2014         15       371   74.200000           57  148.400000
# 2015         17       372   31.000000           53  121.967213
# 2016         12       284   40.571429           64  135.238095
# 2017         15       290   26.363636           61  116.000000
# 2018         15       455   75.833333           79  150.662252
# 2019         12       416  104.000000           84  134.627832
# 2020/21      12       200   25.000000           47  116.279070
# 2021         11       114   16.285714           18  106.542056
# 2022         12       232   33.142857           50  123.404255

# %% [markdown]
# ### `Q-9` Using both dataset, make a dataframe as described below
#
# Data Frame columns-> `['PlayerOfThematch', 'BattingFigure', 'BowlingFigure']`
#
# * BattingFigure->`<runs>/<balls>`
# * BowlingFigure->`<wicket>/<runs-conceded>`
#
# DataFrame should have one record for each match.
#
# Say 'V Kohli' got POM award then in dataset include his batting figure of that match. Say he scored 112runs in 76 balls. And he hasn't bowled so Bowling Figure will be NaN
# ```
# PlayerOfThematch BattingFigure BowlingFigure
# V Kohli          112/76         nan
#
# ```

# %%
# code here
df = balls.merge(matches[["ID", "Player_of_Match"]], on="ID")
batterdf = df[df.batter == df.Player_of_Match].copy()
batterdf["IsBatsmanBall"] = batterdf["extra_type"].apply(lambda x: 1 if x != "wides" else 0)
batter = batterdf.groupby(["ID", "batter"], as_index=False)[["batsman_run", "IsBatsmanBall"]].sum()
batter["BattingFigure"] = batter[["batsman_run", "IsBatsmanBall"]].apply(lambda x: '/'.join(map(str, x.values)), axis = 1)
batter.rename(columns = {"batter": "PlayerOfMatch"}, inplace = True)
batter.head()
# Out:
#        ID PlayerOfMatch  batsman_run  IsBatsmanBall BattingFigure
# 0  335982   BB McCullum          158             73        158/73
# 1  335983    MEK Hussey          116             54        116/54
# 2  335985    MV Boucher           39             19         39/19
# 3  335986     DJ Hussey           38             43         38/43
# 4  335987     SR Watson           76             49         76/49

# %%
bowlerdf = df[df.bowler == df.Player_of_Match].copy()
bowlerdf["IsBowlerWicket"] = bowlerdf["kind"].apply(lambda x: 1 if x in ["caught", 'caught and bowled', 'bowled', 'stumped','lbw', 'hit wicket'] else 0)
bowlerdf["BowlerRun"] = bowlerdf.extra_type.apply(lambda x: 0 if x in ["legbyes", "byes"] else 1) * bowlerdf["total_run"]
bowler = bowlerdf.groupby(["ID", "bowler"], as_index=False)[["IsBowlerWicket", "BowlerRun"]].sum()
bowler["BowlingFigure"] = bowler[["IsBowlerWicket", "BowlerRun"]].apply(lambda x: '/'.join(map(str, x.values)), axis = 1)
bowler.rename(columns = {"bowler": "PlayerOfMatch"}, inplace = True)
bowler.head()
# Out:
#        ID PlayerOfMatch  IsBowlerWicket  BowlerRun BowlingFigure
# 0  335984   MF Maharoof               2         11          2/11
# 1  335986     DJ Hussey               1         35          1/35
# 2  335987     SR Watson               0         39          0/39
# 3  335990     YK Pathan               2         20          2/20
# 4  335992     SR Watson               2         20          2/20

# %%
batter.merge(bowler, on=["ID", "PlayerOfMatch"], how = "outer").drop(columns = ["batsman_run", "IsBatsmanBall", "IsBowlerWicket", "BowlerRun"]).head()
# Out:
#        ID PlayerOfMatch BattingFigure BowlingFigure
# 0  335982   BB McCullum        158/73           NaN
# 1  335983    MEK Hussey        116/54           NaN
# 2  335984   MF Maharoof           NaN          2/11
# 3  335985    MV Boucher         39/19           NaN
# 4  335986     DJ Hussey         38/43          1/35

# %%
pd.concat((q1,q2,q3,items))
# Out:
#     order_id  quantity item_id  choice_description_id item_price  \
# 0        1.0       1.0       1                    1.0     $3.39
# 1        1.0       1.0       2                    2.0     $3.39
# 2        2.0       2.0       4                    3.0    $16.98
# 3        4.0       1.0       7                    6.0     $9.25
# 4        6.0       1.0       9                    8.0     $8.75
# ..       ...       ...     ...                    ...        ...
# 45       NaN       NaN      45                    NaN        NaN
# 46       NaN       NaN      46                    NaN        NaN
# 47       NaN       NaN      47                    NaN        NaN
# 48       NaN       NaN      48                    NaN        NaN
# 49       NaN       NaN      49                    NaN        NaN
#
#               item_name
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 45  Barbacoa Salad Bowl
# 46                Salad
# 47  Veggie Crispy Tacos
# 48         Veggie Salad
# 49       Carnitas Salad
#
# [4672 rows x 6 columns]

# %%
q1 = q1.merge(items, on="item_id", how="left")
q2 = q2.merge(items, on="item_id", how="left")
q3 = q3.merge(items, on="item_id", how="left")

# %%
q1.groupby(["item_name"])["quantity"].sum().sort_values(ascending=False)
# Out:
# item_name
# Chicken Bowl                             367
# Chicken Burrito                          287
# Chips and Guacamole                      258
# Steak Burrito                            191
# Canned Soft Drink                        147
# Steak Bowl                               115
# Chips                                    111
# Bottled Water                            105
# Chips and Fresh Tomato Salsa              73
# Chicken Salad Bowl                        65
# Canned Soda                               59
# Chicken Soft Tacos                        58
# Side of Chips                             52
# Veggie Burrito                            52
# Barbacoa Burrito                          48
# Carnitas Bowl                             44
# Veggie Bowl                               41
# Barbacoa Bowl                             34
# Carnitas Burrito                          32
# 6 Pack Soft Drink                         31
# Chicken Crispy Tacos                      29
# Steak Crispy Tacos                        23
# Carnitas Soft Tacos                       23
# Steak Soft Tacos                          22
# Chips and Tomatillo Green Chili Salsa     20
# Chips and Tomatillo Red Chili Salsa       19
# Nantucket Nectar                          17
# Steak Salad Bowl                          15
# Chips and Tomatillo-Green Chili Salsa     14
# Chips and Roasted Chili Corn Salsa        12
# Izze                                      11
# Barbacoa Soft Tacos                       10
# Chips and Tomatillo-Red Chili Salsa       10
# Veggie Salad Bowl                          8
# Chips and Roasted Chili-Corn Salsa         7
# Barbacoa Crispy Tacos                      6
# Barbacoa Salad Bowl                        5
# Chicken Salad                              4
# Carnitas Crispy Tacos                      4
# Bowl                                       3
# Burrito                                    3
# Salad                                      2
# Steak Salad                                2
# Crispy Tacos                               2
# Carnitas Salad Bowl                        2
# Veggie Soft Tacos                          2
# Chips and Mild Fresh Tomato Salsa          1
# Carnitas Salad                             1
# Veggie Salad                               1
# Name: quantity, dtype: int64

# %%
q2.groupby(["item_name"])["quantity"].sum().sort_values(ascending=False)
# Out:
# item_name
# Chicken Bowl                             394
# Chicken Burrito                          304
# Chips and Guacamole                      248
# Canned Soft Drink                        204
# Steak Burrito                            195
# Chips                                    119
# Bottled Water                            106
# Steak Bowl                               106
# Canned Soda                               67
# Chicken Soft Tacos                        62
# Side of Chips                             58
# Chicken Salad Bowl                        58
# Chips and Fresh Tomato Salsa              57
# Veggie Bowl                               46
# Veggie Burrito                            45
# Barbacoa Burrito                          43
# Steak Soft Tacos                          34
# Barbacoa Bowl                             32
# Chips and Tomatillo Red Chili Salsa       31
# Carnitas Burrito                          28
# Carnitas Bowl                             27
# Chips and Tomatillo Green Chili Salsa     25
# 6 Pack Soft Drink                         24
# Chicken Crispy Tacos                      21
# Chips and Tomatillo-Green Chili Salsa     19
# Carnitas Soft Tacos                       17
# Steak Salad Bowl                          16
# Barbacoa Soft Tacos                       15
# Chips and Tomatillo-Red Chili Salsa       15
# Steak Crispy Tacos                        13
# Nantucket Nectar                          12
# Chips and Roasted Chili Corn Salsa        11
# Chips and Roasted Chili-Corn Salsa        11
# Veggie Salad Bowl                         10
# Izze                                       9
# Veggie Soft Tacos                          6
# Barbacoa Crispy Tacos                      6
# Veggie Salad                               5
# Barbacoa Salad Bowl                        5
# Chicken Salad                              5
# Carnitas Crispy Tacos                      4
# Carnitas Salad Bowl                        4
# Burrito                                    3
# Steak Salad                                2
# Bowl                                       1
# Veggie Crispy Tacos                        1
# Name: quantity, dtype: int64

# %%
q3.groupby(["item_name"])["quantity"].sum().sort_values(ascending=False)
# Out:
# Series([], Name: quantity, dtype: object)

# %%
q1.groupby(["item_name"])["item_price"].sum().sort_values(ascending=False)
# Out:
# item_name
# Carnitas Soft Tacos                      $9.25 $9.25 $9.25 $8.99 $8.99 $9.25 $9.25 $9.2...
# Barbacoa Soft Tacos                      $9.25 $9.25 $9.25 $11.75 $11.75 $9.25 $11.75 $...
# Steak Soft Tacos                         $9.25 $8.99 $9.25 $9.25 $8.99 $9.25 $9.25 $8.9...
# Barbacoa Burrito                         $9.25 $11.75 $11.75 $8.99 $8.99 $9.25 $9.25 $9...
# Steak Salad                                                                   $8.99 $8.99
# Steak Crispy Tacos                       $8.99 $8.69 $9.25 $9.25 $9.25 $9.25 $11.75 $8....
# Carnitas Bowl                            $8.99 $11.75 $11.48 $8.99 $8.99 $23.50 $9.25 $...
# Carnitas Salad                                                                      $8.99
# Chicken Soft Tacos                       $8.75 $8.75 $8.49 $8.49 $17.50 $8.75 $10.98 $8...
# Veggie Soft Tacos                                                             $8.75 $8.75
# Chicken Salad Bowl                       $8.75 $22.50 $22.50 $8.75 $17.50 $8.75 $8.75 $...
# Chicken Crispy Tacos                     $8.75 $17.50 $11.25 $8.75 $11.25 $8.75 $11.25 ...
# Chicken Burrito                          $8.49 $8.49 $10.98 $10.98 $8.49 $10.98 $11.25 ...
# Veggie Burrito                           $8.49 $11.25 $11.25 $11.25 $8.49 $8.49 $8.49 $...
# Veggie Salad                                                                        $8.49
# Burrito                                                                 $7.40 $7.40 $7.40
# Salad                                                                         $7.40 $7.40
# Crispy Tacos                                                                  $7.40 $7.40
# 6 Pack Soft Drink                        $6.49 $6.49 $6.49 $6.49 $6.49 $6.49 $6.49 $6.4...
# Chips and Guacamole                      $4.45 $4.45 $4.45 $4.45 $4.45 $4.45 $4.45 $4.4...
# Nantucket Nectar                         $3.39 $3.39 $3.39 $3.39 $6.78 $3.39 $3.39 $6.7...
# Izze                                     $3.39 $3.39 $3.39 $3.39 $3.39 $3.39 $3.39 $3.3...
# Chips and Mild Fresh Tomato Salsa                                                   $3.00
# Steak Salad Bowl                         $23.78 $11.89 $23.78 $11.89 $11.89 $11.89 $9.3...
# Bowl                                                                               $22.20
# Chips and Tomatillo Green Chili Salsa    $2.95 $2.95 $5.90 $2.95 $5.90 $2.95 $2.95 $2.9...
# Chips and Tomatillo Red Chili Salsa      $2.95 $2.95 $2.95 $2.95 $5.90 $2.95 $2.95 $2.9...
# Chips and Roasted Chili Corn Salsa       $2.95 $2.95 $2.95 $2.95 $2.95 $5.90 $2.95 $2.9...
# Chips and Fresh Tomato Salsa             $2.39 $2.95 $2.95 $2.39 $2.95 $2.95 $2.95 $2.2...
# Chips and Tomatillo-Red Chili Salsa       $2.39 $2.39 $2.39 $7.17 $2.39 $2.39 $2.39 $2.39
# Chips and Tomatillo-Green Chili Salsa    $2.39 $2.39 $2.39 $2.39 $2.39 $2.39 $2.39 $2.3...
# Chips and Roasted Chili-Corn Salsa              $2.39 $2.39 $2.39 $2.39 $2.39 $2.39 $2.39
# Canned Soda                              $2.18 $1.09 $1.09 $1.09 $2.18 $1.09 $1.09 $1.0...
# Chips                                    $2.15 $2.15 $4.30 $2.15 $2.15 $2.15 $2.15 $2.1...
# Chicken Bowl                             $16.98 $11.25 $8.49 $11.25 $8.75 $8.75 $11.25 ...
# Barbacoa Salad Bowl                                      $11.89 $11.89 $11.89 $9.39 $9.39
# Carnitas Salad Bowl                                                         $11.89 $11.89
# Carnitas Burrito                         $11.75 $9.25 $9.25 $9.25 $11.75 $8.99 $9.25 $9...
# Steak Burrito                            $11.75 $8.99 $8.99 $8.99 $8.99 $8.99 $8.99 $8....
# Carnitas Crispy Tacos                                                 $11.75 $17.98 $9.25
# Barbacoa Bowl                            $11.75 $11.75 $9.25 $11.48 $9.25 $9.25 $9.25 $...
# Steak Bowl                               $11.75 $11.75 $11.48 $9.25 $11.75 $11.75 $9.25...
# Barbacoa Crispy Tacos                                     $11.48 $9.25 $8.99 $18.50 $8.99
# Veggie Salad Bowl                        $11.25 $8.75 $11.25 $8.75 $8.75 $11.25 $11.25 ...
# Veggie Bowl                              $11.25 $8.49 $11.25 $8.75 $8.75 $11.25 $8.49 $...
# Chicken Salad                                                    $10.98 $8.49 $8.49 $8.19
# Side of Chips                            $1.69 $1.69 $1.69 $1.69 $1.69 $1.69 $1.69 $1.6...
# Canned Soft Drink                        $1.25 $1.25 $1.25 $1.25 $1.25 $1.25 $1.25 $1.2...
# Bottled Water                            $1.09 $1.09 $1.50 $1.50 $1.50 $3.00 $1.50 $1.5...
# Name: item_price, dtype: object

# %%
q1
# Out:
#       order_id  quantity  item_id  choice_description_id item_price  \
# 0            1         1        1                      1     $3.39
# 1            1         1        2                      2     $3.39
# 2            2         2        4                      3    $16.98
# 3            4         1        7                      6     $9.25
# 4            6         1        9                      8     $8.75
# ...        ...       ...      ...                    ...        ...
# 2270      1831         1       16                      0     $1.50
# 2271      1833         1        6                    276    $11.75
# 2272      1833         1        6                    904    $11.75
# 2273      1834         1       20                    303     $8.75
# 2274      1834         1       20                     30     $8.75
#
#                  item_name
# 0                     Izze
# 1         Nantucket Nectar
# 2             Chicken Bowl
# 3         Steak Soft Tacos
# 4     Chicken Crispy Tacos
# ...                    ...
# 2270         Bottled Water
# 2271         Steak Burrito
# 2272         Steak Burrito
# 2273    Chicken Salad Bowl
# 2274    Chicken Salad Bowl
#
# [2275 rows x 6 columns]

# %%
q1["item_price"]=q1.apply(func1, axis=1)

# %%
def func1(row):
    a= str(row["item_price"]).lstrip("$")
    return float(a)

# %%
df22["item_price"]=df22.apply(func1, axis=1)

# %%
q1.groupby(["item_name"])["item_price"].sum().sort_values(ascending=False).head(1)
# Out:
# item_name
# Chicken Bowl    3525.72
# Name: item_price, dtype: float64

# %%
df22.groupby("order_id")["item_price"].sum().mean()
# Out:
# 18.81142857142869

# %%
df22
# Out:
#         order_id quantity  item_id choice_description_id item_price  \
# Q1 0           1        1        1                     1       3.39
#    1           1        1        2                     2       3.39
#    2           2        2        4                     3      16.98
#    3           4        1        7                     6       9.25
#    4           6        1        9                     8       8.75
# ...          ...      ...      ...                   ...        ...
# Q2 2342     1829        1       23                    92    $11.25
#    2343     1830        1       23                  1043    $11.25
#    2344     1832        1       10                   116     $8.75
#    2345     1832        1        8                     0     $4.45
#    2346     1834        1       20                   515    $11.25
#
#                     item_name
# Q1 0                     Izze
#    1         Nantucket Nectar
#    2             Chicken Bowl
#    3         Steak Soft Tacos
#    4     Chicken Crispy Tacos
# ...                       ...
# Q2 2342        Veggie Burrito
#    2343        Veggie Burrito
#    2344    Chicken Soft Tacos
#    2345   Chips and Guacamole
#    2346    Chicken Salad Bowl
#
# [4622 rows x 6 columns]
