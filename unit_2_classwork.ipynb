# %% [markdown]
# # 1.You are given marks of 12 students in 5 subjects: Math, Physics, Chemistry, Biology, and English.
#
# 1. Create a DataFrame df_scores with random integer values between 40 and 100.
#
# 2. Analyze the relationship between all subjects.
#
# 3. Visualize the relationships using a heatmap such that:
#
# The color scale is centered properly for negative to positive relationships
#
# Strong positive and negative relationships are clearly distinguishable using contrasting colors
#
# Each cell is clearly separated by visible borders
#
# The exact numeric relationship values are displayed inside each cell
#
# A legend for colors is visible

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
np.random.seed(42)

df_scores = pd.DataFrame({
    "Math": np.random.randint(40, 100, 12),
    "Physics": np.random.randint(40, 100, 12),
    "Chemistry": np.random.randint(40, 100, 12),
    "Biology": np.random.randint(40, 100, 12),
    "English": np.random.randint(40, 100, 12)
})

print(df_scores)
# Out:
#     Math  Physics  Chemistry  Biology  English
# 0     78       50         69       66       96
# 1     91       63         77       98       42
# 2     68       92         41       81       76
# 3     54       75         99       67       90
# 4     82       79         60       99       46
# 5     47       63         72       55       60
# 6     60       42         51       54       48
# 7     78       61         97       86       78
# 8     97       92         61       90       57
# 9     58       41         83       83       43
# 10    62       63         64       94       64
# 11    50       83         88       91       99

# %%
sns.heatmap(df_scores.corr(), vmin=-1,vmax=1,linecolor="black",linewidths=2,annot=True,cbar=True,cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# # 2. You are given employee salary data across multiple departments. Each department has both male and female employees.
#
# 1. Create a DataFrame df_employee with:
#
# Departments: IT, HR, Finance, Marketing
#
# Gender: Male / Female
#
# Salary: random realistic salary values
#
# 2. Visualize the salary distribution such that:
#
# Each department is shown separately along one axis
#
# Salary spread is clearly visible using quartiles and medians
#
# Within each department, comparison between male and female employees is clearly distinguishable
#
# All distributions share the same visual tone (single consistent color)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(42)

df_employee = pd.DataFrame({
    "Department": np.random.choice(["IT", "HR", "Finance", "Marketing"], 40),
    "Gender": np.random.choice(["Male", "Female"], 40),
    "Salary": np.random.randint(30000, 100000, 40)
})

print(df_employee.head())
# Out:
#   Department  Gender  Salary
# 0    Finance    Male   78555
# 1  Marketing    Male   47159
# 2         IT  Female   65920
# 3    Finance  Female   97121
# 4    Finance  Female   99479

# %%
sns.boxplot(data=df_employee, hue= "Gender",x="Department", y="Salary",color="red" )
# Out:
# <ipython-input-5-eab4d0d54f48>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.boxplot(data=df_employee, hue= "Gender",x="Department", y="Salary",color="red" )
# <Axes: xlabel='Department', ylabel='Salary'>

# %% [markdown]
# # 3. You are given student performance data.
#
# Tasks:
#
# 1. Create a DataFrame df_performance with:
#
# Number of hours studied
#
# Marks obtained
#
# Gender of student
#
# Section (A, B, C)
#
# 2. Visualize the relationship such that:
#
# Study time is placed along the horizontal direction
#
# Marks are represented vertically
#
# Male and female students are distinguished using different colors
#
# Students from different sections are represented using different marker shapes
#
# All data points are clearly visible and slightly larger than default size

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_performance = pd.DataFrame({
    "Hours_Studied": [2, 3, 4, 5, 6, 7, 8, 2.5, 3.5, 6.5, 7.5, 5.5],
    "Marks": [40, 50, 55, 65, 70, 80, 90, 45, 52, 75, 85, 68],
    "Gender": ["Male", "Female", "Male", "Female", "Male", "Female",
               "Male", "Female", "Male", "Female", "Male", "Female"],
    "Section": ["A", "A", "B", "B", "C", "C",
                "A", "B", "C", "A", "B", "C"]
})

print(df_performance)
# Out:
#     Hours_Studied  Marks  Gender Section
# 0             2.0     40    Male       A
# 1             3.0     50  Female       A
# 2             4.0     55    Male       B
# 3             5.0     65  Female       B
# 4             6.0     70    Male       C
# 5             7.0     80  Female       C
# 6             8.0     90    Male       A
# 7             2.5     45  Female       B
# 8             3.5     52    Male       C
# 9             6.5     75  Female       A
# 10            7.5     85    Male       B
# 11            5.5     68  Female       C

# %%
sns.scatterplot(data=df_performance, x="Hours_Studied", y="Marks", hue="Gender",style="Section",s=200)
# Out:
# <Axes: xlabel='Hours_Studied', ylabel='Marks'>

# %% [markdown]
# # 4. you are given order data across different cities and product categories.
#
# 1. Create a DataFrame df_orders containing:
#
# City names
#
# Product categories
#
# Number of orders
#
# 2. Visualize the data such that:
#
# Each city is represented along the horizontal direction
#
# Order counts are shown vertically
#
# Different product categories are distinguished using colors
#
# Bars belonging to the same city appear side-by-side (not stacked)
#
# Each bar also has a unique pattern style based on category
#
# Exact order values are displayed on the bars
#
# When hovering, additional category information is visible
#
# The chart has a proper title and a wider rectangular layout
#
# Use a fixed set of three distinct colors

# %%
import pandas as pd
import plotly.express as px

df_orders = pd.DataFrame({
    "City": ["Ahmedabad", "Ahmedabad", "Ahmedabad",
             "Mumbai", "Mumbai", "Mumbai",
             "Delhi", "Delhi", "Delhi"],
    "Category": ["Electronics", "Clothing", "Grocery",
                 "Electronics", "Clothing", "Grocery",
                 "Electronics", "Clothing", "Grocery"],
    "Orders": [120, 90, 150, 200, 140, 180, 170, 110, 160]
})

print(df_orders)
# Out:
#         City     Category  Orders
# 0  Ahmedabad  Electronics     120
# 1  Ahmedabad     Clothing      90
# 2  Ahmedabad      Grocery     150
# 3     Mumbai  Electronics     200
# 4     Mumbai     Clothing     140
# 5     Mumbai      Grocery     180
# 6      Delhi  Electronics     170
# 7      Delhi     Clothing     110
# 8      Delhi      Grocery     160

# %%
px.bar(data_frame=df_orders, color="Category", x="City", y="Orders",pattern_shape="Category", text_auto=True, hover_data=["Category"], barmode="group")
# Out:
# <div>                            <div id="e0a78942-ae25-4397-be35-b371eac9c2d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0a78942-ae25-4397-be35-b371eac9c2d0")) {                    Plotly.newPlot(                        "e0a78942-ae25-4397-be35-b371eac9c2d0",                        [{"alignmentgroup":"True","customdata":[["Electronics"],["Electronics"],["Electronics"]],"hovertemplate":"Category=%{customdata[0]}\u003cbr\u003eCity=%{x}\u003cbr\u003eOrders=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Electronics","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Electronics","offsetgroup":"Electronics","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Ahmedabad","Mumbai","Delhi"],"xaxis":"x","y":[120,200,170],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Clothing"],["Clothing"],["Clothing"]],"hovertemplate":"Category=%{customdata[0]}\u003cbr\u003eCity=%{x}\u003cbr\u003eOrders=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clothing","marker":{"color":"#EF553B","pattern":{"shape":"\u002f"}},"name":"Clothing","offsetgroup":"Clothing","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Ahmedabad","Mumbai","Delhi"],"xaxis":"x","y":[90,140,110],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Grocery"],["Grocery"],["Grocery"]],"hovertemplate":"Category=%{customdata[0]}\u003cbr\u003eCity=%{x}\u003cbr\u003eOrders=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Grocery","marker":{"color":"#00cc96","pattern":{"shape":"\\"}},"name":"Grocery","offsetgroup":"Grocery","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Ahmedabad","Mumbai","Delhi"],"xaxis":"x","y":[150,180,160],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555 ...

# %% [markdown]
# # 5. You are analyzing how advertising impacts revenue across different regions.
#
# 1. Create a DataFrame df_sales with:
#
# Advertising investment
#
# Revenue generated
#
# Region (North, South, East)
#
# Profit earned
#
# 2. Build a visualization such that:
#
# Advertising spend is shown along the horizontal direction
#
# Revenue is represented vertically
#
# Each region is distinguished using different colors and marker shapes
#
# The size of each point reflects profitability
#
# The chart is split into multiple panels, one for each region
#
# The layout is wide and clearly visible

# %%
import pandas as pd
import plotly.express as px

df_sales = pd.DataFrame({
    "Advertising_Spend": [1000, 1500, 2000, 1200, 1800, 2200, 1300, 1700, 2100],
    "Revenue": [5000, 7000, 9000, 5500, 7500, 9500, 6000, 8000, 10000],
    "Region": ["North", "North", "North",
               "South", "South", "South",
               "East", "East", "East"],
    "Profit": [500, 800, 1200, 600, 900, 1300, 550, 850, 1250]
})
df_sales
# Out:
#    Advertising_Spend  Revenue Region  Profit
# 0               1000     5000  North     500
# 1               1500     7000  North     800
# 2               2000     9000  North    1200
# 3               1200     5500  South     600
# 4               1800     7500  South     900
# 5               2200     9500  South    1300
# 6               1300     6000   East     550
# 7               1700     8000   East     850
# 8               2100    10000   East    1250

# %%
px.scatter(data_frame=df_sales, x="Advertising_Spend",y="Revenue", size="Profit", color="Region"
          , facet_col="Region", symbol="Region")
# Out:
# <div>                            <div id="cfad6f0c-4cea-4b61-b926-7dbc3c4c0bd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfad6f0c-4cea-4b61-b926-7dbc3c4c0bd7")) {                    Plotly.newPlot(                        "cfad6f0c-4cea-4b61-b926-7dbc3c4c0bd7",                        [{"hovertemplate":"Region=North\u003cbr\u003eAdvertising_Spend=%{x}\u003cbr\u003eRevenue=%{y}\u003cbr\u003eProfit=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","marker":{"color":"#636efa","size":[500,800,1200],"sizemode":"area","sizeref":3.25,"symbol":"circle"},"mode":"markers","name":"North","orientation":"v","showlegend":true,"x":[1000,1500,2000],"xaxis":"x","y":[5000,7000,9000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=South\u003cbr\u003eAdvertising_Spend=%{x}\u003cbr\u003eRevenue=%{y}\u003cbr\u003eProfit=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#EF553B","size":[600,900,1300],"sizemode":"area","sizeref":3.25,"symbol":"diamond"},"mode":"markers","name":"South","orientation":"v","showlegend":true,"x":[1200,1800,2200],"xaxis":"x2","y":[5500,7500,9500],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Region=East\u003cbr\u003eAdvertising_Spend=%{x}\u003cbr\u003eRevenue=%{y}\u003cbr\u003eProfit=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#00cc96","size":[550,850,1250],"sizemode":"area","sizeref":3.25,"symbol":"square"},"mode":"markers","name":"East","orientation":"v","showlegend":true,"x":[1300,1700,2100],"xaxis":"x3","y":[6000,8000,10000],"yaxis":"y3","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth ...

# %% [markdown]
# # 6. You are given spatial data representing objects in a 3D environment.
#
# Tasks:
#
# 1. Create a DataFrame df_space containing:
#
# Three-dimensional coordinates of objects
#
# A category/type for each object
#
# A value indicating intensity or strength
#
# 2. Visualize the data such that:
#
# Points are positioned across three axes (depth included)
#
# Different object types are distinguished using colors
#
# Points vary in size depending on their intensity
#
# The chart has a clear descriptive heading

# %%
import pandas as pd
import plotly.express as px


df_space = pd.DataFrame({
    "X": [1, 2, 3, 4, 5, 6],
    "Y": [2, 3, 4, 5, 6, 7],
    "Z": [3, 1, 5, 2, 6, 4],
    "Type": ["A", "B", "A", "B", "C", "C"],
    "Magnitude": [10, 20, 15, 25, 18, 30]
})


print(df_space)
# Out:
#    X  Y  Z Type  Magnitude
# 0  1  2  3    A         10
# 1  2  3  1    B         20
# 2  3  4  5    A         15
# 3  4  5  2    B         25
# 4  5  6  6    C         18
# 5  6  7  4    C         30

# %%
px.scatter_3d(data_frame=df_space,x="X",  y="Y", z="Z", color="Type", size="Magnitude", title="Scatter 3d of points")
# Out:
# <div>                            <div id="5796e08a-2139-4eb0-9191-3dc306b05b85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5796e08a-2139-4eb0-9191-3dc306b05b85")) {                    Plotly.newPlot(                        "5796e08a-2139-4eb0-9191-3dc306b05b85",                        [{"hovertemplate":"Type=A\u003cbr\u003eX=%{x}\u003cbr\u003eY=%{y}\u003cbr\u003eZ=%{z}\u003cbr\u003eMagnitude=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"A","marker":{"color":"#636efa","size":[10,15],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"A","scene":"scene","showlegend":true,"x":[1,3],"y":[2,4],"z":[3,5],"type":"scatter3d"},{"hovertemplate":"Type=B\u003cbr\u003eX=%{x}\u003cbr\u003eY=%{y}\u003cbr\u003eZ=%{z}\u003cbr\u003eMagnitude=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"B","marker":{"color":"#EF553B","size":[20,25],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"B","scene":"scene","showlegend":true,"x":[2,4],"y":[3,5],"z":[1,2],"type":"scatter3d"},{"hovertemplate":"Type=C\u003cbr\u003eX=%{x}\u003cbr\u003eY=%{y}\u003cbr\u003eZ=%{z}\u003cbr\u003eMagnitude=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"C","marker":{"color":"#00cc96","size":[18,30],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"C","scene":"scene","showlegend":true,"x":[5,6],"y":[6,7],"z":[6,4],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786" ...

# %% [markdown]
# # 7. You are analyzing health-related measurements of individuals.
#
#  Tasks:
#
# 1. Create a DataFrame df_health with:
#
# Physical attributes (height, weight, BMI, age)
#
# A label indicating whether a person is Fit or Unfit
#
# 2. Build a visualization such that:
#
# All numerical attributes are compared pairwise in a grid format
#
# Each small plot shows the relationship between two variables
#
# Individuals are distinguished based on fitness category using colors
#
# The entire visualization is large and clearly readable (square layout)

# %%
import pandas as pd
import plotly.express as px


df_health = pd.DataFrame({
    "Height": [160, 165, 170, 175, 180, 155, 168, 172],
    "Weight": [55, 65, 70, 75, 85, 50, 68, 72],
    "BMI": [21.5, 23.9, 24.2, 24.5, 26.2, 20.8, 24.1, 24.3],
    "Age": [22, 25, 30, 28, 35, 24, 27, 29],
    "Category": ["Fit", "Fit", "Unfit", "Unfit", "Unfit", "Fit", "Fit", "Unfit"]
})

print(df_health)
# Out:
#    Height  Weight   BMI  Age Category
# 0     160      55  21.5   22      Fit
# 1     165      65  23.9   25      Fit
# 2     170      70  24.2   30    Unfit
# 3     175      75  24.5   28    Unfit
# 4     180      85  26.2   35    Unfit
# 5     155      50  20.8   24      Fit
# 6     168      68  24.1   27      Fit
# 7     172      72  24.3   29    Unfit

# %%
px.scatter_matrix(data_frame=df_health, dimensions=["Height", "Weight","BMI","Age"],color="Category")
# Out:
# <div>                            <div id="92331fed-cb19-4906-a803-6537d7a58988" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92331fed-cb19-4906-a803-6537d7a58988")) {                    Plotly.newPlot(                        "92331fed-cb19-4906-a803-6537d7a58988",                        [{"dimensions":[{"axis":{"matches":true},"label":"Height","values":[160,165,155,168]},{"axis":{"matches":true},"label":"Weight","values":[55,65,50,68]},{"axis":{"matches":true},"label":"BMI","values":[21.5,23.9,20.8,24.1]},{"axis":{"matches":true},"label":"Age","values":[22,25,24,27]}],"hovertemplate":"Category=Fit\u003cbr\u003e%{xaxis.title.text}=%{x}\u003cbr\u003e%{yaxis.title.text}=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fit","marker":{"color":"#636efa","symbol":"circle"},"name":"Fit","showlegend":true,"type":"splom"},{"dimensions":[{"axis":{"matches":true},"label":"Height","values":[170,175,180,172]},{"axis":{"matches":true},"label":"Weight","values":[70,75,85,72]},{"axis":{"matches":true},"label":"BMI","values":[24.2,24.5,26.2,24.3]},{"axis":{"matches":true},"label":"Age","values":[30,28,35,29]}],"hovertemplate":"Category=Unfit\u003cbr\u003e%{xaxis.title.text}=%{x}\u003cbr\u003e%{yaxis.title.text}=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Unfit","marker":{"color":"#EF553B","symbol":"circle"},"name":"Unfit","showlegend":true,"type":"splom"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777 ...

# %% [markdown]
# # 8. You are given temperature data for multiple cities over several days.
#
# Tasks:
#
# 1. Create a DataFrame df_weather containing:
#
# Days (Day 1 to Day 7)
#
# City names
#
# Temperature values
#
# 2. Visualize the data such that:
#
# Time progression is shown along the horizontal direction
#
# Temperature changes are displayed vertically
#
# Each city is represented by a separate colored line
#
# Data points on the lines are clearly marked
#
# When hovering, city information is visible
#
# The chart includes a clear descriptive heading
#
# Use a fixed set of three distinct colors

# %%
import pandas as pd
import plotly.express as px

df_weather = pd.DataFrame({
    "Day": ["Day1","Day2","Day3","Day4","Day5","Day6","Day7",
            "Day1","Day2","Day3","Day4","Day5","Day6","Day7",
            "Day1","Day2","Day3","Day4","Day5","Day6","Day7"],
    "City": ["Ahmedabad"]*7 + ["Mumbai"]*7 + ["Delhi"]*7,
    "Temperature": [
        30, 32, 35, 36, 34, 33, 31,
        28, 29, 30, 31, 30, 29, 28,
        25, 27, 29, 30, 28, 27, 26
    ]
})

print(df_weather)
# Out:
#      Day       City  Temperature
# 0   Day1  Ahmedabad           30
# 1   Day2  Ahmedabad           32
# 2   Day3  Ahmedabad           35
# 3   Day4  Ahmedabad           36
# 4   Day5  Ahmedabad           34
# 5   Day6  Ahmedabad           33
# 6   Day7  Ahmedabad           31
# 7   Day1     Mumbai           28
# 8   Day2     Mumbai           29
# 9   Day3     Mumbai           30
# 10  Day4     Mumbai           31
# 11  Day5     Mumbai           30
# 12  Day6     Mumbai           29
# 13  Day7     Mumbai           28
# 14  Day1      Delhi           25
# 15  Day2      Delhi           27
# 16  Day3      Delhi           29
# 17  Day4      Delhi           30
# 18  Day5      Delhi           28
# 19  Day6      Delhi           27
# 20  Day7      Delhi           26

# %%
px.line(data_frame=df_weather,x="Day", y="Temperature", hover_data="City", color="City", markers=True)
# Out:
# <div>                            <div id="29fc745d-86e0-455c-80d4-57dbaab19e5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29fc745d-86e0-455c-80d4-57dbaab19e5f")) {                    Plotly.newPlot(                        "29fc745d-86e0-455c-80d4-57dbaab19e5f",                        [{"customdata":[["Ahmedabad"],["Ahmedabad"],["Ahmedabad"],["Ahmedabad"],["Ahmedabad"],["Ahmedabad"],["Ahmedabad"]],"hovertemplate":"City=%{customdata[0]}\u003cbr\u003eDay=%{x}\u003cbr\u003eTemperature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ahmedabad","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ahmedabad","orientation":"v","showlegend":true,"x":["Day1","Day2","Day3","Day4","Day5","Day6","Day7"],"xaxis":"x","y":[30,32,35,36,34,33,31],"yaxis":"y","type":"scatter"},{"customdata":[["Mumbai"],["Mumbai"],["Mumbai"],["Mumbai"],["Mumbai"],["Mumbai"],["Mumbai"]],"hovertemplate":"City=%{customdata[0]}\u003cbr\u003eDay=%{x}\u003cbr\u003eTemperature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mumbai","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Mumbai","orientation":"v","showlegend":true,"x":["Day1","Day2","Day3","Day4","Day5","Day6","Day7"],"xaxis":"x","y":[28,29,30,31,30,29,28],"yaxis":"y","type":"scatter"},{"customdata":[["Delhi"],["Delhi"],["Delhi"],["Delhi"],["Delhi"],["Delhi"],["Delhi"]],"hovertemplate":"City=%{customdata[0]}\u003cbr\u003eDay=%{x}\u003cbr\u003eTemperature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Delhi","orientation":"v","showlegend":true,"x":["Day1","Day2","Day3","Day4","Day5","Day6","Day7"],"xaxis":"x","y":[25,27,29,30,28,27,26],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c1 ...

# %% [markdown]
# # 9. You are analyzing the age distribution of a population dataset.
#
# Tasks:
#
# 1. Create a DataFrame df_population containing:
#
# Age of individuals
#
# Gender (Male/Female)
#
# 2. Visualize the distribution such that:
#
# Ages are grouped into multiple equal-width intervals (moderate number of bins)
#
# The frequency of individuals in each interval is displayed
#
# Male and Female distributions are distinguished using different colors and patterns
#
# Each bar clearly shows the exact count of individuals
#
# Use a fixed pair of soft contrasting colors

# %%
import pandas as pd
import plotly.express as px


df_population = pd.DataFrame({
    "Age": [18, 22, 25, 30, 35, 40, 45, 50, 28, 32, 38, 42, 48, 26, 29, 33, 37, 41, 46, 52],
    "Gender": ["Male", "Female", "Male", "Female", "Male", "Female",
               "Male", "Female", "Male", "Female", "Male", "Female",
               "Male", "Female", "Male", "Female", "Male", "Female",
               "Male", "Female"]
})

print(df_population)
# Out:
#     Age  Gender
# 0    18    Male
# 1    22  Female
# 2    25    Male
# 3    30  Female
# 4    35    Male
# 5    40  Female
# 6    45    Male
# 7    50  Female
# 8    28    Male
# 9    32  Female
# 10   38    Male
# 11   42  Female
# 12   48    Male
# 13   26  Female
# 14   29    Male
# 15   33  Female
# 16   37    Male
# 17   41  Female
# 18   46    Male
# 19   52  Female

# %%
px.histogram(data_frame=df_population, x="Age", histfunc="count",pattern_shape="Gender", nbins=10, color="Gender", text_auto=True)
# Out:
# <div>                            <div id="24a6ef12-fdac-4926-920e-ce5bc8a4e4d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24a6ef12-fdac-4926-920e-ce5bc8a4e4d3")) {                    Plotly.newPlot(                        "24a6ef12-fdac-4926-920e-ce5bc8a4e4d3",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"count","hovertemplate":"Gender=Male\u003cbr\u003eAge=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Male","nbinsx":10,"offsetgroup":"Male","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":[18,25,35,45,28,38,48,29,37,46],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"count","hovertemplate":"Gender=Female\u003cbr\u003eAge=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female","marker":{"color":"#EF553B","pattern":{"shape":"\u002f"}},"name":"Female","nbinsx":10,"offsetgroup":"Female","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":[22,30,40,50,32,42,26,33,41,52],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity ...

# %% [markdown]
# # 10. You are given monthly expense data categorized into different spending types.
#
# Tasks:
#
# Create a DataFrame df_expense containing:
#
# Expense categories (like Food, Rent, Travel, Shopping)
#
# Amount spent in each category
#
# Visualize the data such that:
#
# Each category is represented as a portion of a circle based on its contribution
#
# Use a set of soft, visually distinct colors
#
# The chart includes a clear title
#
# Enhance the visualization further:
#
# Display both the percentage and category name inside each slice
#
# Ensure labels are placed inside the slices
#
# Slightly separate (highlight) one important category from the rest

# %%
import pandas as pd
import plotly.express as px

df_expense = pd.DataFrame({
    "Category": ["Food", "Rent", "Travel", "Shopping"],
    "Amount": [12000, 25000, 8000, 10000]
})

print(df_expense)
# Out:
#    Category  Amount
# 0      Food   12000
# 1      Rent   25000
# 2    Travel    8000
# 3  Shopping   10000

# %%
fig=px.pie(data_frame=df_expense, values="Amount", names="Category", color_discrete_sequence=["red","black", "blue"],hole=0.2)
fig.update_traces(textinfo="percent+label", textposition="inside", pull=[0.2,0.0,0.0,0.0])
# Out:
# <div>                            <div id="3e443151-d21d-408c-b909-29761331f680" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e443151-d21d-408c-b909-29761331f680")) {                    Plotly.newPlot(                        "3e443151-d21d-408c-b909-29761331f680",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.2,"hovertemplate":"Category=%{label}\u003cbr\u003eAmount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Food","Rent","Travel","Shopping"],"legendgroup":"","name":"","showlegend":true,"values":[12000,25000,8000,10000],"type":"pie","pull":[0.2,0.0,0.0,0.0],"textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatt ...

# %% [markdown]
# # 11. You are designing a transport connectivity model between cities.
# Tasks:
#
# 1. Represent 4 cities as points in a network
#
# Define direct connections such that:
#
# City1 is connected to City2
#
# City2 connects to City3
#
# City3 connects to City4
#
# City1 also has a direct route to City4
#
# 2. Visualize the network such that:
#
# Each city name is clearly visible on the graph
#
# Nodes appear large and prominent
#
# All nodes share a uniform color theme
#
# Connections between cities are thick and clearly visible
#
# Edges have a neutral tone

# %%
import networkx as nx
g=nx.DiGraph()
g.add_nodes_from(["City1","City2", "City3", "City4"])
g.add_edges_from([("City1", "City2"),("City2", "City3"),("City3", "City4"),("City4", "City1")])
nx.draw(g, with_labels=True, node_size=1000, node_color=["red", "orange", "green","blue"], width=5)

# %% [markdown]
# # In a customer dataset, you have a column representing customer incomes. You want to categorize incomes into 'Low', 'Medium', and 'High' groups. Incomes below 30000 are 'Low', incomes between 30000 and 70000 are 'Medium', and incomes above 70000 are 'High'. Write a code to achieve this assuming the dataset has a column named 'income'.

# %%
df=pd.DataFrame({"salary":[30000,40000,5000,60000,70000,45000]})

# %% [markdown]
# # Convert the Department column into dummy variables
#
# Keep the original DataFrame structure intact (other columns should remain unchanged)
#
# Use a prefix "Dept" for new columns
#
# Drop the original Department column
#
# Store the result in a new DataFrame df_encoded

# %%
d1= pd.get_dummies(df)

# %%
df
# Out:
#        0
# 0  30000
# 1  40000
# 2   5000
# 3  60000
# 4  70000
# 5  45000

# %%
df["Cat"]= np.where(df.salary>70000,"high",np.where(df.salary>50000,"mid", "low"))

# %%
df
# Out:
#    salary  Cat
# 0   30000  low
# 1   40000  low
# 2    5000  low
# 3   60000  mid
# 4   70000  mid
# 5   45000  low
